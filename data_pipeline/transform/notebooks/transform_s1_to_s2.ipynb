# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import yaml, os

from utils.spark_path import (
    get_current_year_month_week_path,
    get_latest_year_month_week_path
)

# %%
# ============================================================
# Spark
# ============================================================
spark = (
    SparkSession.builder
    .appName("silver_s1_to_s2")
    .master("spark://spark-master:7077")
    .config("spark.sql.adaptive.enabled", "true")
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true")
    .config("spark.sql.shuffle.partitions", "200")
    .getOrCreate()
)
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
# Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/21 11:49:58 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Config

# %%
# ============================================================
# Config
# ============================================================

CONFIG_PATH = "./config.yaml"

with open(CONFIG_PATH, "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

ROOT = cfg["data_lake"]["root"]
LAYERS = cfg["data_lake"]["layers"]

# Input Path
s1_toji_list_base = os.path.join(
    ROOT,
    LAYERS["silver"]["stages"]["s1"]["domains"]["toji_list"]["paths"]["parquet"]
)
s1_toji_list_path = get_latest_year_month_week_path(spark, s1_toji_list_base)

s2_ownership_base = os.path.join(
    ROOT,
    LAYERS["silver"]["stages"]["s2"]["domains"]["ownership_inference"]["paths"]["parquet"]
)
s2_ownership_path = get_latest_year_month_week_path(spark, s2_ownership_base)

# Output Path
s2_toji_owner_match_base = os.path.join(
    ROOT,
    LAYERS["silver"]["stages"]["s2"]["domains"]["toji_owner_match"]["paths"]["parquet"]
)
s2_toji_owner_match_path = get_current_year_month_week_path(s2_toji_owner_match_base)

s2_toji_owner_match_partition_cols = LAYERS["silver"]["stages"]["s2"]["domains"]["toji_owner_match"].get("partition")

print("[PATH] s1_toji_list_path   =", s1_toji_list_path)
print("[PATH] s2_ownership_path   =", s2_ownership_path)
print("[PATH] s2_toji_owner_match_path   =", s2_toji_owner_match_path)
# Out:
# [PATH] s1_toji_list_path   = /opt/spark/data/silver/s1/toji_list/year=2026/month=02/week=03
# [PATH] s2_ownership_path   = /opt/spark/data/silver/s2/ownership_inference/year=2026/month=02/week=02
# [PATH] s2_toji_owner_match_path   = /opt/spark/data/silver/s2/toji_owner_match/year=2026/month=02/week=03

# %% [markdown]
# # 데이터 로드 (Bronze 식당 정보 + S0 주소, 토지_건축물)

# %%
toji_df = (
    spark.read.parquet(s1_toji_list_path)
)

owner_df = (
    spark.read.parquet(s2_ownership_path)
    .dropDuplicates(
        ["주소", "본번", "소유권변동일자"]
    )
)

print("toji_df")
toji_df.printSchema()
toji_df.show(2)
print("owner_df")
owner_df.printSchema()
owner_df.show(2)
# Out:
# toji_df
# root
#  |-- 법정동명: string (nullable = true)
#  |-- 본번: string (nullable = true)
#  |-- 고유번호: string (nullable = true)
#  |-- 지목: string (nullable = true)
#  |-- 공유인수: long (nullable = true)
#  |-- 소유권변동일자: string (nullable = true)
#  |-- 부번: string (nullable = true)
#  |-- 관리_건축물대장_PK: string (nullable = true)
#  |-- 대장_구분_코드: string (nullable = true)
#  |-- 옥외자주식면적: double (nullable = true)
#  |-- 유휴부지_면적: double (nullable = true)
#  |-- 업체명: string (nullable = true)
#  |-- 업종: string (nullable = true)
#  |-- 대표자: string (nullable = true)
#  |-- 대표자_수: integer (nullable = true)
#  |-- 도로명주소: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- region: string (nullable = true)
#
# +---------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------+------------+------+---------+----------------------------+-----------------+-----------------+------+
# |                   법정동명|본번|           고유번호|지목|공유인수|소유권변동일자|부번|관리_건축물대장_PK|대장_구분_코드|옥외자주식면적|유휴부지_면적|                    업체명|        업종|대표자|대표자_수|                  도로명주소|        longitude|         latitude|region|
# +---------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------+------------+------+---------+----------------------------+-----------------+-----------------+------+
# |경기도 가평군 가평읍 금대리| 585|4182025034105850000|  대|       2|    2020-10-15|NULL|         113016187|             1|           0.0|      -499.63|(주)클럽피쉬연수원레스토랑|  일반음식점| 이*섭|        1|경기도 가평군 북한강변로 160|127.5259318567397|37.74735473695793|  경기|
# |경기도 가평군 가평읍 금대리| 585|4182025034105850000|  대|       2|    2020-10-15|NULL|         113016187|             1|           0.0|      -499.63|      신응수강변요양병원점|위탁급식영업| 신*수|        1|경기도 가평군 북한강변로 160|127.5259318567397|37.74735473695793|  경기|
# +---------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------+------------+------+---------+----------------------------+-----------------+-----------------+------+
# only showing top 2 rows
# owner_df
# root
#  |-- 주소: string (nullable = true)
#  |-- 본번: string (nullable = true)
#  |-- 부번: string (nullable = true)
#  |-- 지주: string (nullable = true)
#  |-- 소유권변동일자: string (nullable = true)
#  |-- region: string (nullable = true)
#
# +---------------------------+----+----+------+--------------+------+
# |                       주소|본번|부번|  지주|소유권변동일자|region|
# +---------------------------+----+----+------+--------------+------+
# |경기도 용인시 처인구 고림동| 193|   4|신기훈|    2023-12-26|  경기|
# |경기도 용인시 처인구 고림동| 193|NULL|오제천|    2025-07-14|  경기|
# +---------------------------+----+----+------+--------------+------+
# only showing top 2 rows

# %%
t = toji_df.alias("t")
o = owner_df.alias("o")

toji_with_owner_df = (
    t.join(
        o,
        (F.col("t.법정동명") == F.col("o.주소")) &
        (F.col("t.본번") == F.col("o.본번")) &
        (F.col("t.소유권변동일자") == F.col("o.소유권변동일자")) &
        (F.col("t.region") == F.col("o.region")),
        how="inner"
    )
    .select(
        "t.*",                     
        F.col("o.지주").alias("지주"),
    )
)

print("row 수:", toji_with_owner_df.count())
toji_with_owner_df \
    .orderBy(F.col("유휴부지_면적").asc()) \
    .show(10, truncate=False)
# Out:
# row 수: 5889
# +-----------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------------+----------+------+---------+---------------------------------------+------------------+-----------------+------+------+
# |법정동명                     |본번|고유번호           |지목|공유인수|소유권변동일자|부번|관리_건축물대장_PK|대장_구분_코드|옥외자주식면적|유휴부지_면적|업체명                          |업종      |대표자|대표자_수|도로명주소                             |longitude         |latitude         |region|지주  |
# +-----------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------------+----------+------+---------+---------------------------------------+------------------+-----------------+------+------+
# |경기도 용인시 처인구 김량장동|254 |4146110100102540001|대  |4       |2023-12-20    |1   |1116125911        |1             |0.0           |-1505.77     |나율                            |휴게음식점|김*하 |1        |경기도 용인시 처인구 금령로55번길 12   |127.20258167142065|37.2360684109224 |경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540001|대  |4       |2023-12-20    |1   |1116125911        |1             |0.0           |-1505.77     |쥬벨베이커리                    |제과점영업|박*철 |1        |경기도 용인시 처인구 금령로55번길 12   |127.20258167142065|37.2360684109224 |경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540001|대  |4       |2023-12-20    |1   |1116125911        |1             |0.0           |-1505.77     |(주)지에스리테일용인점          |휴게음식점|허*홍 |1        |경기도 용인시 처인구 금령로55번길 12   |127.20258167142065|37.2360684109224 |경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540421|대  |4       |2023-12-20    |421 |111615504         |1             |166.0         |-955.6       |용인공원동태탕섞어탕(중앙시장)  |일반음식점|이*일 |1        |경기도 용인시 처인구 금령로71번길 15   |127.2034405408726 |37.23638948159756|경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540421|대  |4       |2023-12-20    |421 |111615504         |1             |166.0         |-955.6       |다정집 뼈해장국 용인중앙시장본점|일반음식점|황*찬 |1        |경기도 용인시 처인구 금령로71번길 15   |127.2034405408726 |37.23638948159756|경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540421|대  |4       |2023-12-20    |421 |111615504         |1             |166.0         |-955.6       |명품고기 금고기(본점)           |일반음식점|박*영 |1        |경기도 용인시 처인구 금령로71번길 15   |127.2034405408726 |37.23638948159756|경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540421|대  |4       |2023-12-20    |421 |111615504         |1             |166.0         |-955.6       |김가네숯불닭갈비                |일반음식점|김*환 |2        |경기도 용인시 처인구 금령로71번길 15   |127.2034405408726 |37.23638948159756|경기  |박한익|
# |경기도 용인시 처인구 김량장동|254 |4146110100102540421|대  |4       |2023-12-20    |421 |111615504         |1             |166.0         |-955.6       |장미막창                        |일반음식점|임*홍 |1        |경기도 용인시 처인구 금령로71번길 15   |127.2034405408726 |37.23638948159756|경기  |박한익|
# |경기도 용인시 처인구 역북동  |437 |4146110200104370004|대  |3       |2016-12-15    |4   |1116136784        |1             |0.0           |-570.88      |채움                            |일반음식점|배*희 |1        |경기도 용인시 처인구 중부대로1331번길 7|127.19287365988546|37.2361208203053 |경기  |인재후|
# |경기도 용인시 처인구 역북동  |437 |4146110200104370004|대  |3       |2016-12-15    |4   |1116136784        |1             |0.0           |-570.88      |집에가기 전                     |일반음식점|김*숙 |1        |경기도 용인시 처인구 중부대로1331번길 7|127.19287365988546|37.2361208203053 |경기  |인재후|
# +-----------------------------+----+-------------------+----+--------+--------------+----+------------------+--------------+--------------+-------------+--------------------------------+----------+------+---------+---------------------------------------+------------------+-----------------+------+------+
# only showing top 10 rows

# %%
toji_with_owner_df.printSchema()
# Out:
# root
#  |-- 법정동명: string (nullable = true)
#  |-- 본번: string (nullable = true)
#  |-- 고유번호: string (nullable = true)
#  |-- 지목: string (nullable = true)
#  |-- 공유인수: long (nullable = true)
#  |-- 소유권변동일자: string (nullable = true)
#  |-- 부번: string (nullable = true)
#  |-- 관리_건축물대장_PK: string (nullable = true)
#  |-- 대장_구분_코드: string (nullable = true)
#  |-- 옥외자주식면적: double (nullable = true)
#  |-- 유휴부지_면적: double (nullable = true)
#  |-- 업체명: string (nullable = true)
#  |-- 업종: string (nullable = true)
#  |-- 대표자: string (nullable = true)
#  |-- 대표자_수: integer (nullable = true)
#  |-- 도로명주소: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- region: string (nullable = true)
#  |-- 지주: string (nullable = true)

# %%
(
    toji_with_owner_df
    .write.mode("overwrite")
    .partitionBy(*s2_toji_owner_match_partition_cols)
    .parquet(s2_toji_owner_match_path)
)
print("✅ saved:", s2_toji_owner_match_path)
# Out:
# [Stage 19:>                                                         (0 + 4) / 4]
# ✅ saved: /opt/spark/data/silver/s2/toji_owner_match/year=2026/month=02/week=03

# %%
spark.stop()
