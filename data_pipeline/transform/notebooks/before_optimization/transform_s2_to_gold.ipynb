# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

import yaml, os

from utils.spark_path import (
    get_current_year_month_week_path,
    get_latest_year_month_week_path
)

# %%
# ============================================================
# Spark
# ============================================================
spark = (
    SparkSession.builder
    .appName("silver_s1_to_s2")
    .master("spark://spark-master:7077")
    .config("spark.sql.adaptive.enabled", "true")
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true")
    .config("spark.sql.shuffle.partitions", "200")
    .getOrCreate()
)
# Out:
# 26/02/21 03:34:20 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# # Config

# %%
# ============================================================
# Config
# ============================================================

CONFIG_PATH = "./config.yaml"

with open(CONFIG_PATH, "r", encoding="utf-8") as f:
    cfg = yaml.safe_load(f)

ROOT = cfg["data_lake"]["root"]
LAYERS = cfg["data_lake"]["layers"]

# Input Path
s2_toji_owner_match_base = os.path.join(
    ROOT,
    LAYERS["silver"]["stages"]["s2"]["domains"]["toji_owner_match"]["paths"]["parquet"]
)
s2_toji_owner_match_path = get_latest_year_month_week_path(spark, s2_toji_owner_match_base)


# Output Path
gold_restaurant_master_base = os.path.join(
    ROOT,
    LAYERS["gold"]["domains"]["restaurant_master"]["paths"]["parquet"]
)
gold_restaurant_master_path = get_current_year_month_week_path(gold_restaurant_master_base)

gold_restaurant_master_partition_cols = LAYERS["gold"]["domains"]["restaurant_master"].get("partition")


print("[PATH] s2_toji_owner_match_path   =", s2_toji_owner_match_path)
print("[PATH] gold_restaurant_master_path   =", gold_restaurant_master_path)
# Out:
# [PATH] s2_toji_owner_match_path   = /opt/spark/data/silver/s2/toji_owner_match/year=2026/month=02/week=03
# [PATH] gold_restaurant_master_path   = /opt/spark/data/gold/restaurant_master/year=2026/month=02/week=03

# %%
toji_owner_df = (
    spark.read.parquet(s2_toji_owner_match_path)
)

toji_owner_df.printSchema()
# Out:
# root
#  |-- 법정동명: string (nullable = true)
#  |-- 본번: string (nullable = true)
#  |-- 고유번호: string (nullable = true)
#  |-- 지목: string (nullable = true)
#  |-- 공유인수: long (nullable = true)
#  |-- 소유권변동일자: string (nullable = true)
#  |-- 부번: string (nullable = true)
#  |-- 관리_건축물대장_PK: string (nullable = true)
#  |-- 유휴부지_면적: double (nullable = true)
#  |-- 업체명: string (nullable = true)
#  |-- 업종: string (nullable = true)
#  |-- 대표자: string (nullable = true)
#  |-- 대표자_수: integer (nullable = true)
#  |-- 도로명주소: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- 지주: string (nullable = true)
#  |-- region: string (nullable = true)

# %%
parking_max_df = (
    toji_owner_df
    .groupBy("법정동명", "본번", "지주", "부번", "region")
    .agg(F.max("유휴부지_면적").alias("유휴부지_면적(max)"))
)

parking_sum_df = (
    parking_max_df
    .groupBy("법정동명", "본번", "지주", "region")
    .agg(
        F.sum("유휴부지_면적(max)").alias("유휴부지_면적")
    )
)

print(parking_sum_df.count())
parking_sum_df.show(10, truncate=False)
# Out:
# 3112
# +----------------------------------+----+------------+------+------------------+
# |법정동명                          |본번|지주        |region|유휴부지_면적     |
# +----------------------------------+----+------------+------+------------------+
# |경기도 용인시 처인구 남사읍 방아리|844 |백영미      |경기  |2565.0            |
# |경기도 용인시 처인구 모현읍 초부리|75  |이철희      |경기  |34.0              |
# |경기도 용인시 처인구 포곡읍 삼계리|59  |버          |경기  |1327.0            |
# |경기도 용인시 처인구 남사읍 봉무리|658 |김태홍      |경기  |1446.0            |
# |경기도 용인시 처인구 원삼면 문촌리|6   |버          |경기  |1478.6            |
# |경기도 용인시 처인구 역북동       |605 |최경서      |경기  |248.0             |
# |경기도 용인시 처인구 유방동       |750 |버          |경기  |314.0             |
# |경기도 용인시 처인구 역북동       |418 |사해환      |경기  |10.47             |
# |경기도 용인시 처인구 원삼면 사암리|140 |버          |경기  |565.15            |
# |경기도 용인시 처인구 원삼면 두창리|85  |주식회사라진|경기  |2386.6499999999996|
# +----------------------------------+----+------------+------+------------------+
# only showing top 10 rows

# %%
final_df = (
    toji_owner_df.alias("r")
    .join(
        parking_sum_df.alias("p"),
        on=["법정동명", "본번", "지주", "region"],
        how="left"
    )
)

final_df.printSchema()
# Out:
# root
#  |-- 법정동명: string (nullable = true)
#  |-- 본번: string (nullable = true)
#  |-- 지주: string (nullable = true)
#  |-- region: string (nullable = true)
#  |-- 고유번호: string (nullable = true)
#  |-- 지목: string (nullable = true)
#  |-- 공유인수: long (nullable = true)
#  |-- 소유권변동일자: string (nullable = true)
#  |-- 부번: string (nullable = true)
#  |-- 관리_건축물대장_PK: string (nullable = true)
#  |-- 유휴부지_면적: double (nullable = true)
#  |-- 업체명: string (nullable = true)
#  |-- 업종: string (nullable = true)
#  |-- 대표자: string (nullable = true)
#  |-- 대표자_수: integer (nullable = true)
#  |-- 도로명주소: string (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- 유휴부지_면적: double (nullable = true)

# %%
final_df.show()
# Out:
# +-----------------------------+----+------+------+-------------------+----+--------+--------------+----+------------------+-------------------+-------------------------+----------+------+---------+---------------------------------+------------------+------------------+-------------------+
# |                     법정동명|본번|  지주|region|           고유번호|지목|공유인수|소유권변동일자|부번|관리_건축물대장_PK|      유휴부지_면적|                   업체명|      업종|대표자|대표자_수|                       도로명주소|         longitude|          latitude|      유휴부지_면적|
# +-----------------------------+----+------+------+-------------------+----+--------+--------------+----+------------------+-------------------+-------------------------+----------+------+---------+---------------------------------+------------------+------------------+-------------------+
# |  경기도 용인시 처인구 고림동| 984|박연화|  경기|4146110600109840000|  대|       8|    2017-03-30|NULL|    11161100387728|-116.33000000000001|         역시풍천민물장어|일반음식점| 이*희|        1|경기도 용인시 처인구 경안천로 230|127.21897716117445| 37.25163320018901| -37.55000000000001|
# |  경기도 용인시 처인구 고림동| 984|박연화|  경기|4146110600109840004|  답|       8|    2017-03-30|   4|              NULL|              78.78|                     NULL|      NULL|  NULL|     NULL|                             NULL|              NULL|              NULL| -37.55000000000001|
# |경기도 용인시 처인구 김량장동| 294|섬민식|  경기|4146110100102940006|  대|       0|    1989-05-29|   6|        1116121679|               88.6|                   장미네|일반음식점| 이*미|        1| 경기도 용인시 처인구 금령로27...| 127.1984527380665|37.235279496330136|               88.6|
# |경기도 용인시 처인구 김량장동| 294|이진순|  경기|4146110100102940014|  대|       2|    2022-02-15|  14|        1116136357| -95.31000000000002|               맥스피드PC|휴게음식점| 피*우|        1|   경기도 용인시 처인구 금령로 23|127.19887138661127|37.234943302131725| -95.31000000000002|
# |경기도 용인시 처인구 김량장동| 294|신석균|  경기|4146110100102940025|  대|       0|    2020-04-27|  25|        1116121054|  60.39999999999999|                 김밥여행|일반음식점| 윤*석|        1| 경기도 용인시 처인구 금령로13...|127.19794675805264| 37.23538378903779|  60.39999999999999|
# |경기도 용인시 처인구 김량장동| 294|한승수|  경기|4146110100102940000|  대|       0|    1988-09-19|NULL|        1116124566|-63.860000000000014|               달려라호프|일반음식점| 서*희|        1| 경기도 용인시 처인구 금령로13...| 127.1979912071423| 37.23569339304665|             156.04|
# |경기도 용인시 처인구 김량장동| 294|한승수|  경기|4146110100102940000|  대|       0|    1988-09-19|NULL|        1116124566|-63.860000000000014|    본스치킨 용인김량장점|일반음식점| 김*주|        1| 경기도 용인시 처인구 금령로13...| 127.1979912071423| 37.23569339304665|             156.04|
# |경기도 용인시 처인구 김량장동| 294|한승수|  경기|4146110100102940000|  대|       0|    1988-09-19|NULL|        1116124566|-63.860000000000014|                 오동족발|일반음식점| 김*석|        1| 경기도 용인시 처인구 금령로13...| 127.1979912071423| 37.23569339304665|             156.04|
# |경기도 용인시 처인구 김량장동| 294|한승수|  경기|4146110100102940000|  대|       0|    1988-09-19|NULL|        1116124566|-63.860000000000014|       닭치는대로발라먹자|일반음식점| 이*순|        1| 경기도 용인시 처인구 금령로13...| 127.1979912071423| 37.23569339304665|             156.04|
# |경기도 용인시 처인구 김량장동| 294|김묘순|  경기|4146110100102940007|  대|       0|    1989-05-08|   7|        1116132778|  59.15999999999998|                   나고야|일반음식점| 강*석|        1| 경기도 용인시 처인구 금령로27...|127.19854569713421| 37.23527675094286|  59.15999999999998|
# |경기도 용인시 처인구 김량장동| 294|류재준|  경기|4146110100102940026|  대|       0|    2025-09-15|  26|        1116128030|  69.14999999999999|               카리브포차|일반음식점| 김*기|        1| 경기도 용인시 처인구 금령로13...|127.19798150477065|37.235506831212724|  69.14999999999999|
# |경기도 용인시 처인구 김량장동| 294|류재준|  경기|4146110100102940026|  대|       0|    2025-09-15|  26|        1116128030|  69.14999999999999|        노모어피자 처인점|일반음식점| 양*식|        1| 경기도 용인시 처인구 금령로13...|127.19798150477065|37.235506831212724|  69.14999999999999|
# |경기도 용인시 처인구 김량장동| 294|한승수|  경기|4146110100102940027|  대|       0|    1988-09-28|  27|              NULL|              219.9|                     NULL|      NULL|  NULL|     NULL|                             NULL|              NULL|              NULL|             156.04|
# |경기도 용인시 처인구 김량장동| 294|안장수|  경기|4146110100102940013|  대|       0|    2021-07-12|  13|        1116136253|  99.75999999999999|            삼청동 김치찜|일반음식점| 엄*원|        1|   경기도 용인시 처인구 금령로 25|127.19903343478718|37.234938175382524|  99.75999999999999|
# |경기도 용인시 처인구 김량장동| 294|안장수|  경기|4146110100102940013|  대|       0|    2021-07-12|  13|        1116136253|  99.75999999999999|포트캔커피 용인처인구청점|일반음식점| 채*선|        1|   경기도 용인시 처인구 금령로 25|127.19903343478718|37.234938175382524|  99.75999999999999|
# |경기도 용인시 처인구 김량장동| 294|안장수|  경기|4146110100102940013|  대|       0|    2021-07-12|  13|        1116136253|  99.75999999999999| 미스사이공용인처인구청점|일반음식점| 채*선|        1|   경기도 용인시 처인구 금령로 25|127.19903343478718|37.234938175382524|  99.75999999999999|
# |경기도 용인시 처인구 김량장동| 294|박은미|  경기|4146110100102940021|  대|       5|    2013-06-28|  21|        1116135754|-118.91999999999999|           고기가맛있는집|일반음식점| 김*숙|        1| 경기도 용인시 처인구 금령로13...|127.19790583082123| 37.23522836477736|-118.91999999999999|
# |경기도 용인시 처인구 김량장동| 294|임성진|  경기|4146110100102940020|  대|       0|    1990-06-18|  20|        1116118835|            136.925|              이삭 토스트|일반음식점| 송*미|        1|   경기도 용인시 처인구 금령로 15|127.19801041384657| 37.23493502055538|            136.925|
# |경기도 용인시 처인구 김량장동| 294|박종대|  경기|4146110100102940009|  대|       1|    2006-09-04|   9|        1116126056|-12.399999999999991|                 정성이네|일반음식점| 이*성|        1| 경기도 용인시 처인구 금령로27...|127.19875701478105| 37.23529318553101|-12.399999999999991|
# |경기도 용인시 처인구 김량장동| 294|박종대|  경기|4146110100102940009|  대|       1|    2006-09-04|   9|        1116126056|-12.399999999999991|             봉명동내커피|일반음식점| 김*서|        1| 경기도 용인시 처인구 금령로27...|127.19875701478105| 37.23529318553101|-12.399999999999991|
# +-----------------------------+----+------+------+-------------------+----+--------+--------------+----+------------------+-------------------+-------------------------+----------+------+---------+---------------------------------+------------------+------------------+-------------------+
# only showing top 20 rows
# 26/02/21 04:04:02 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.6: worker lost: Not receiving heartbeat for 60 seconds
# 26/02/21 04:04:02 ERROR TaskSchedulerImpl: Lost executor 1 on 172.18.0.5: worker lost: Not receiving heartbeat for 60 seconds

# %%
def name_match(col_rep, col_owner):
    return (
        col_rep.isNotNull() &
        col_owner.isNotNull() &
        (F.length(col_rep) >= 2) &
        (F.length(col_rep) == F.length(col_owner)) &
        (F.substring(col_rep, 1, 1) == F.substring(col_owner, 1, 1)) &
        (
            # 2글자: 첫 글자만 비교
            (F.length(col_owner) == 2) |
            # 3글자 이상: 첫 + 끝 글자 비교
            (F.substring(col_rep, F.length(col_rep), 1) ==
            F.substring(col_owner, F.length(col_owner), 1))
        )
    )

# %%
spark.stop()
