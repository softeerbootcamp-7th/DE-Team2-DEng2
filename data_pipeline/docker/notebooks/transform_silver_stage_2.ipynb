# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql import Window
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, LongType
import datetime as dt
from pyspark.sql import functions as F
from pyspark.sql import Window
import os
import re
import datetime as dt

# %%
# =========================
# 설정
# =========================
REGION = "경기"
SIGUNGU_CODE = "41461"  # None이면 전체
sigungu_dir = SIGUNGU_CODE if SIGUNGU_CODE else "all"

# Spark Session 설정
spark = SparkSession.builder \
    .appName(f'silver_stage_1_{REGION}_{sigungu_dir}') \
    .master("spark://spark-master:7077") \
    .config("spark.sql.adaptive.enabled", "true") \
    .config("spark.sql.adaptive.coalescePartitions.enabled", "true") \
    .config("spark.sql.shuffle.partitions", "400") \
    .getOrCreate()
# Out:
# Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
# Picked up JAVA_TOOL_OPTIONS: -Dfile.encoding=UTF-8
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/13 10:57:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
OUT_BASE  = "/opt/spark/data/output/silver_stage_1/main"
TOJI_BASE = "/opt/spark/data/tojidaejang/parquet"

# =========================
# 1) output: 직전 분기 마지막 달 계산
# =========================
today = dt.date.today()
cur_q = (today.month - 1) // 3 + 1
prev_q = cur_q - 1
prev_q_year = today.year
if prev_q == 0:
    prev_q = 4
    prev_q_year -= 1

prev_q_last_month = prev_q * 3  # 3/6/9/12

out_path = (
    f"{OUT_BASE}/year={prev_q_year}/month={prev_q_last_month:02d}"
    f"/region={REGION}/sigungu={sigungu_dir}"
)

print("[output] path =", out_path)

# =========================
# 2) tojidaejang: 가장 최근 (year, month) 파티션 찾기
#    - 디렉토리 구조: .../year=YYYY/month=MM/region=경기
# =========================
def find_latest_year_month(base: str, region: str):
    year_re  = re.compile(r"^year=(\d{4})$")
    month_re = re.compile(r"^month=(\d{2})$")

    candidates = []
    for yname in os.listdir(base):
        ym = year_re.match(yname)
        if not ym:
            continue
        y = int(ym.group(1))
        ydir = os.path.join(base, yname)

        if not os.path.isdir(ydir):
            continue

        for mname in os.listdir(ydir):
            mm = month_re.match(mname)
            if not mm:
                continue
            m = int(mm.group(1))
            mdir = os.path.join(ydir, mname)
            if not os.path.isdir(mdir):
                continue

            # region 파티션 존재 여부 체크
            rdir = os.path.join(mdir, f"region={region}")
            if os.path.isdir(rdir):
                candidates.append((y, m))

    if not candidates:
        raise FileNotFoundError(f"no partitions found under {base} for region={region}")

    return max(candidates)  # (year, month)

latest_y, latest_m = find_latest_year_month(TOJI_BASE, REGION)

toji_daejang_path = f"{TOJI_BASE}/year={latest_y}/month={latest_m:02d}/region={REGION}"
print("[tojidaejang] latest =", f"{latest_y}-{latest_m:02d}")
print("[tojidaejang] path   =", toji_daejang_path)

# =========================
# 3) Read parquet
# =========================
silver1_df = spark.read.option("mergeSchema", "false").parquet(out_path)
toji_daejang_df    = spark.read.option("mergeSchema", "false").parquet(toji_daejang_path)
# Out:
# [output] path = /opt/spark/data/output/silver_stage_1/main/year=2025/month=12/region=경기/sigungu=41461
# [tojidaejang] latest = 2026-01
# [tojidaejang] path   = /opt/spark/data/tojidaejang/parquet/year=2026/month=01/region=경기

# %%
from pyspark.sql import functions as F

silver_k = (
    silver1_df
    .withColumn("dong_key", F.trim(F.col("법정동명")))
    .withColumn("bonbun_key", F.trim(F.col("본번")))
    .withColumn("date_key", F.trim(F.col("소유권변동일자")))
)

toji_k = (
    toji_daejang_df
    .withColumn("dong_key", F.trim(F.col("법정동")))
    .withColumn("bonbun_key", F.trim(F.col("본번")))
    .withColumn("date_key", F.trim(F.col("소유권변동일자")))
)

joined_df = (
    silver_k
    .join(
        toji_k.select(
            "dong_key",
            "bonbun_key",
            "date_key",
            "지주"
        ),
        on=["dong_key", "bonbun_key", "date_key"],
        how="left"
    )
)

joined_df = joined_df.drop("dong_key", "bonbun_key", "date_key")

# %%
silver1_df.show(1, truncate=False)
# Out:
# +-----------------------------+----+-------------------+----+--------------+--------------+--------+----+--------+----+------------------+--------------+------------+------+----------------------------------------+----------------+----------------+----------------+----------------+----------------+------+
# |법정동명                     |본번|고유번호           |지번|소유권변동원인|소유권변동일자|토지면적|지목|공시지가|부번|관리_건축물대장_PK|옥외자주식면적|상호명      |지점명|도로명주소                              |상권업종대분류명|상권업종중분류명|상권업종소분류명|경도            |위도            |대표자|
# +-----------------------------+----+-------------------+----+--------------+--------------+--------+----+--------+----+------------------+--------------+------------+------+----------------------------------------+----------------+----------------+----------------+----------------+----------------+------+
# |경기도 용인시 처인구 김량장동|4   |4146110100100040002|4-2 |소유권이전    |2025-10-27    |27.7    |대  |2019000 |2   |1116120527        |0             |브레드스토리|NULL  |경기도 용인시 처인구 백옥대로1068번길 12|음식            |기타 간이       |빵/도넛         |127.211755829105|37.2293033185446|박*찬 |
# +-----------------------------+----+-------------------+----+--------------+--------------+--------+----+--------+----+------------------+--------------+------------+------+----------------------------------------+----------------+----------------+----------------+----------------+----------------+------+
# only showing top 1 row

# %%
from pyspark.sql import functions as F

dup_groups_df = (
    silver1_df
    .groupBy("법정동명", "본번", "부번", "소유권변동일자")
    .count()
    .filter(F.col("count") > 1)
)

expanded_dup_df = (
    silver1_df
    .join(
        dup_groups_df.select(
            "법정동명", "본번", "부번", "소유권변동일자"
        ),
        on=["법정동명", "본번", "부번", "소유권변동일자"],
        how="inner"
    )
)
# Out:
# +---------------------------+----+----+--------------+-----+
# |법정동명                   |본번|부번|소유권변동일자|count|
# +---------------------------+----+----+--------------+-----+
# |경기도 용인시 처인구 고림동|195 |1   |2010-07-15    |1    |
# |경기도 용인시 처인구 고림동|195 |4   |2025-03-10    |1    |
# |경기도 용인시 처인구 고림동|195 |6   |1993-05-19    |1    |
# |경기도 용인시 처인구 고림동|195 |7   |2022-06-08    |1    |
# |경기도 용인시 처인구 고림동|208 |13  |2025-02-28    |1    |
# |경기도 용인시 처인구 고림동|208 |14  |2006-11-17    |1    |
# |경기도 용인시 처인구 고림동|208 |2   |2006-11-17    |1    |
# |경기도 용인시 처인구 고림동|208 |5   |2006-11-17    |1    |
# |경기도 용인시 처인구 고림동|208 |6   |2006-11-17    |1    |
# |경기도 용인시 처인구 고림동|208 |9   |2006-11-17    |1    |
# |경기도 용인시 처인구 고림동|342 |NULL|2017-06-07    |4    |
# |경기도 용인시 처인구 고림동|342 |1   |1998-04-01    |1    |
# |경기도 용인시 처인구 고림동|360 |NULL|2021-01-14    |1    |
# |경기도 용인시 처인구 고림동|360 |2   |2021-11-11    |15   |
# |경기도 용인시 처인구 고림동|360 |3   |2016-08-09    |3    |
# |경기도 용인시 처인구 고림동|370 |2   |2013-10-01    |1    |
# |경기도 용인시 처인구 고림동|370 |5   |2013-10-01    |1    |
# |경기도 용인시 처인구 고림동|458 |1   |2019-10-28    |1    |
# |경기도 용인시 처인구 고림동|458 |13  |2008-03-21    |1    |
# |경기도 용인시 처인구 고림동|458 |14  |2019-12-23    |1    |
# |경기도 용인시 처인구 고림동|458 |19  |2008-01-23    |1    |
# |경기도 용인시 처인구 고림동|458 |2   |2012-12-26    |1    |
# |경기도 용인시 처인구 고림동|458 |20  |2019-12-23    |1    |
# |경기도 용인시 처인구 고림동|458 |21  |2008-03-21    |1    |
# |경기도 용인시 처인구 고림동|458 |55  |2008-03-21    |1    |
# |경기도 용인시 처인구 고림동|458 |56  |2019-12-23    |1    |
# |경기도 용인시 처인구 고림동|458 |57  |2008-03-21    |1    |
# |경기도 용인시 처인구 고림동|464 |NULL|2020-03-23    |1    |
# |경기도 용인시 처인구 고림동|464 |1   |2023-03-15    |1    |
# |경기도 용인시 처인구 고림동|479 |NULL|2001-10-16    |1    |
# |경기도 용인시 처인구 고림동|503 |11  |2012-06-14    |1    |
# |경기도 용인시 처인구 고림동|503 |118 |2012-03-12    |1    |
# |경기도 용인시 처인구 고림동|503 |129 |2012-03-12    |1    |
# |경기도 용인시 처인구 고림동|503 |16  |2013-08-09    |1    |
# |경기도 용인시 처인구 고림동|503 |17  |2002-10-17    |1    |
# |경기도 용인시 처인구 고림동|503 |18  |2019-12-18    |1    |
# |경기도 용인시 처인구 고림동|503 |19  |2016-06-01    |1    |
# |경기도 용인시 처인구 고림동|503 |22  |2002-10-17    |1    |
# |경기도 용인시 처인구 고림동|503 |23  |2001-06-29    |1    |
# |경기도 용인시 처인구 고림동|503 |25  |2012-03-12    |1    |
# |경기도 용인시 처인구 고림동|503 |26  |1987-03-04    |1    |
# |경기도 용인시 처인구 고림동|503 |62  |2024-10-17    |1    |
# |경기도 용인시 처인구 고림동|503 |64  |2004-05-03    |1    |
# |경기도 용인시 처인구 고림동|503 |67  |2024-10-17    |1    |
# |경기도 용인시 처인구 고림동|503 |70  |1981-04-16    |1    |
# |경기도 용인시 처인구 고림동|503 |73  |2012-03-12    |1    |
# |경기도 용인시 처인구 고림동|503 |86  |2019-11-26    |1    |
# |경기도 용인시 처인구 고림동|503 |88  |2018-01-23    |1    |
# |경기도 용인시 처인구 고림동|503 |92  |2004-04-20    |1    |
# |경기도 용인시 처인구 고림동|503 |93  |2002-05-17    |1    |
# +---------------------------+----+----+--------------+-----+
# only showing top 50 rows

# %%
grouped_df = (
    joined_df
    .groupBy("법정동명", "본번", "지주")
    .agg(
        F.count("*").alias("cnt"),
        # 그룹 내 관리_건축물대장_PK가 하나라도 있으면 1 이상
        F.sum(
            F.col("관리_건축물대장_PK").isNotNull().cast("int")
        ).alias("has_building_pk")
    )
    # 전부 NULL인 그룹 제거
    .filter(F.col("has_building_pk") > 0)
    .drop("has_building_pk")
)
valid_groups_df = grouped_df.select(
    "법정동명",
    "본번",
    "지주"
)

# %%
expanded_df = (
    joined_df
    .join(
        valid_groups_df,
        on=["법정동명", "본번", "지주"],
        how="inner"
    )
)

# %%
silver_stage_1.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 silver_stage_1.printSchema()
#
# NameError: name 'silver_stage_1' is not defined

# %%
expanded_df.select(
    "법정동명",
    "본번",
    "상호명",
    "지주",
    "소유권변동일자",
    "대표자",
    "부번",
    "지목",
    "토지면적",
    "관리_건축물대장_PK",
    "옥외자주식면적"
).orderBy(
    "법정동명",
    "본번",
    "소유권변동일자",
    "지주"
).show(55, truncate=False)
# Out:
# +---------------------------+----+--------------------+------+--------------+------+----+--------+--------+----------------------+--------------+
# |법정동명                   |본번|상호명              |지주  |소유권변동일자|대표자|부번|지목    |토지면적|관리_건축물대장_PK    |옥외자주식면적|
# +---------------------------+----+--------------------+------+--------------+------+----+--------+--------+----------------------+--------------+
# |경기도 용인시 처인구 고림동|195 |흥인                |한다솜|2022-06-08    |NULL  |7   |대      |265.0   |1116130236            |0             |
# |경기도 용인시 처인구 고림동|208 |정가는밥상          |김광식|2006-11-17    |조*희 |2   |대      |771.0   |11161100387371        |23            |
# |경기도 용인시 처인구 고림동|208 |NULL                |김광식|2006-11-17    |NULL  |5   |전      |40.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|208 |NULL                |김광식|2006-11-17    |NULL  |6   |도로    |57.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|208 |NULL                |김광식|2006-11-17    |NULL  |9   |전      |9.0     |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|208 |NULL                |김광식|2006-11-17    |NULL  |14  |대      |1.0     |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|342 |잘만든치킨굿킨      |김종회|1998-04-01    |유*숙 |1   |대      |488.0   |1116137176            |23            |
# |경기도 용인시 처인구 고림동|342 |황주집              |이영기|2017-06-07    |조*준 |NULL|대      |1483.0  |1116134146            |92            |
# |경기도 용인시 처인구 고림동|342 |황주집              |이영기|2017-06-07    |이*미 |NULL|대      |1483.0  |1116134146            |92            |
# |경기도 용인시 처인구 고림동|342 |진구네김치찌개      |이영기|2017-06-07    |조*준 |NULL|대      |1483.0  |1116134146            |92            |
# |경기도 용인시 처인구 고림동|342 |진구네김치찌개      |이영기|2017-06-07    |이*미 |NULL|대      |1483.0  |1116134146            |92            |
# |경기도 용인시 처인구 고림동|360 |커피에반하다        |권병천|2016-08-09    |윤*주 |3   |대      |866.0   |1116125475            |11.5          |
# |경기도 용인시 처인구 고림동|360 |커피에반하다        |권병천|2016-08-09    |권*인 |3   |대      |866.0   |1116125475            |11.5          |
# |경기도 용인시 처인구 고림동|360 |커피에반하다        |권병천|2016-08-09    |박*정 |3   |대      |866.0   |1116125475            |11.5          |
# |경기도 용인시 처인구 고림동|360 |고집                |정도옹|2021-11-11    |이*구 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |고집                |정도옹|2021-11-11    |황*숙 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |고집                |정도옹|2021-11-11    |송*란 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |고집                |정도옹|2021-11-11    |김*인 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |고집                |정도옹|2021-11-11    |이*조 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |르꼬르뷔제          |정도옹|2021-11-11    |이*구 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |르꼬르뷔제          |정도옹|2021-11-11    |황*숙 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |르꼬르뷔제          |정도옹|2021-11-11    |송*란 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |르꼬르뷔제          |정도옹|2021-11-11    |김*인 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |르꼬르뷔제          |정도옹|2021-11-11    |이*조 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |해적포차２          |정도옹|2021-11-11    |이*구 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |해적포차２          |정도옹|2021-11-11    |황*숙 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |해적포차２          |정도옹|2021-11-11    |송*란 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |해적포차２          |정도옹|2021-11-11    |김*인 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|360 |해적포차２          |정도옹|2021-11-11    |이*조 |2   |대      |1454.0  |1116120666            |46            |
# |경기도 용인시 처인구 고림동|370 |치카케이크          |이근재|2013-10-01    |NULL  |2   |대      |210.0   |1116129490            |11.5          |
# |경기도 용인시 처인구 고림동|370 |NULL                |이근재|2013-10-01    |NULL  |5   |답      |52.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|458 |가마솥한우소머리국밥|강순진|2012-12-26    |이*경 |2   |대      |638.0   |1116124122            |46            |
# |경기도 용인시 처인구 고림동|458 |NULL                |강순진|2019-10-28    |NULL  |1   |전      |1431.0  |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|464 |슬린트커피          |장시철|2020-03-23    |변*은 |NULL|대      |1300.0  |11161100465531        |50            |
# |경기도 용인시 처인구 고림동|464 |제니스키즈카페      |장시철|2023-03-15    |장*우 |1   |공장용지|2246.0  |11161100464762        |132.5         |
# |경기도 용인시 처인구 고림동|479 |운향능이오리백숙    |최유석|2001-10-16    |김*숙 |NULL|대      |760.0   |1116134539            |34.5          |
# |경기도 용인시 처인구 고림동|503 |까치골오리돌구이    |김희철|2013-08-09    |김*희 |16  |대      |271.0   |11161100318176        |11.5          |
# |경기도 용인시 처인구 고림동|505 |두남자이야기        |주천성|2015-07-14    |한*숙 |7   |대      |660.0   |11161100359894        |11.5          |
# |경기도 용인시 처인구 고림동|505 |NULL                |주천성|2015-07-14    |NULL  |8   |도로    |235.0   |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|505 |NULL                |주천성|2015-07-14    |NULL  |25  |답      |1267.0  |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|505 |NULL                |주천성|2017-09-15    |NULL  |31  |구거    |36.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|540 |우리정육점식당      |박장배|2022-06-02    |박*호 |2   |대      |1295.0  |11161100478617        |123           |
# |경기도 용인시 처인구 고림동|540 |NULL                |박장배|2022-06-02    |NULL  |16  |구거    |11.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|540 |NULL                |박장배|2022-06-02    |NULL  |15  |도로    |6.0     |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|547 |카페블룸스          |정금철|2014-06-16    |김*순 |14  |대      |786.0   |1000000000000000158030|75            |
# |경기도 용인시 처인구 고림동|547 |NULL                |정금철|2014-06-16    |NULL  |15  |전      |4182.0  |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|547 |NULL                |정금철|2014-06-16    |NULL  |16  |도로    |203.0   |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|599 |NULL                |박용성|2018-12-07    |NULL  |17  |도로    |74.0    |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|599 |큰집                |박용성|2018-12-07    |박*성 |18  |대      |511.0   |11161100456536        |46            |
# |경기도 용인시 처인구 고림동|599 |김사부              |지명식|2020-12-09    |김*실 |6   |대      |660.0   |11161100432953        |46            |
# |경기도 용인시 처인구 고림동|599 |김사부              |지명식|2020-12-09    |김*실 |6   |대      |660.0   |11161100432953        |46            |
# |경기도 용인시 처인구 고림동|599 |누들보쌈            |지명식|2020-12-09    |김*실 |6   |대      |660.0   |11161100432953        |46            |
# |경기도 용인시 처인구 고림동|599 |누들보쌈            |지명식|2020-12-09    |김*실 |6   |대      |660.0   |11161100432953        |46            |
# |경기도 용인시 처인구 고림동|736 |NULL                |최명숙|2016-11-01    |NULL  |1   |주차장  |440.0   |NULL                  |NULL          |
# |경기도 용인시 처인구 고림동|736 |배스킨라빈스        |최명숙|2017-07-18    |배*주 |26  |대      |754.0   |11161100439413        |394.92        |
# +---------------------------+----+--------------------+------+--------------+------+----+--------+--------+----------------------+--------------+
# only showing top 55 rows
